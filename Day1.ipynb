# %% [markdown]
# ------------------------
#
# ````SQL
#
# CREATE TABLE table_name (
#     day DATE,
#     temp INT
# );
#
# INSERT INTO table_name (day, temp) VALUES
# ('2024-01-01', 30),
# ('2024-01-02', 32),   -- higher
# ('2024-01-03', 31),
# ('2024-01-04', 35),   -- higher
# ('2024-01-05', 35),
# ('2024-01-06', 36),   -- higher
# ('2024-01-07', 33),
# ('2024-01-08', 34),   -- higher
# ('2024-01-09', 29),
# ('2024-01-10', 30);   -- higher
#
# SELect * FROM table_name;
#
# -- 1. Find the days when temperature was higher than its previous day.
# WITH CTE1 AS(SELECT day, temp,
# LAG(temp,1) OVER(order BY day) AS Previous_temp
# From table_name)
#
# Select day, temp From CTE1 where temp > Previous_temp;

# %% [markdown]
# ----------------------------------------
